# %%
import pandas as pd

# %%
data=pd.read_csv("/home/user/Downloads/fertilizer_recommendation_unclean.csv")

# %%
data
# Out:
#      Soil_Type    Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0         Clay        NaN      23.176586        0.335118
# 1         Silt   5.453217      57.352151        0.245066
# 2          NaN   8.229938      41.595209        1.114318
# 3         Clay   5.097788      13.897686        1.229014
# 4          NaN   7.594949            NaN        0.883794
# ...        ...        ...            ...             ...
# 9995      Silt        NaN      36.331983        0.745274
# 9996      Clay   4.784560            NaN        0.928590
# 9997    Loamy-  78.346197      40.385449        1.144741
# 9998     Loamy   8.020147      47.152632        1.587846
# 9999     Sandy   5.727448      72.451710        1.039178
#
#       Electrical_Conductivity  Nitrogen_Level  Phosphorus_Level  \
# 0                    1.197623       61.326369         33.637166
# 1                    0.187012             NaN         48.048418
# 2                    2.125256       42.623678               NaN
# ...

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isnull().sum()
# Out:
# Soil_Type                      941
# Soil_pH                        911
# Soil_Moisture                  953
# Organic_Carbon                 968
# Electrical_Conductivity        943
# Nitrogen_Level                 980
# Phosphorus_Level               993
# Potassium_Level                983
# Temperature                    976
# Humidity                       980
# Rainfall                       945
# Crop_Type                      913
# Crop_Growth_Stage              980
# Season                         892
# Irrigation_Type                963
# Previous_Crop                  963
# Region                         877
# Fertilizer_Used_Last_Season    996
# Yield_Last_Season              953
# Recommended_Fertilizer         936
# dtype: int64

# %%
data[data['Soil_pH'].isnull()]
# Out:
#      Soil_Type  Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0         Clay      NaN      23.176586        0.335118
# 7       Sandy-      NaN      39.176457        0.587708
# 11        Clay      NaN      13.788126        8.456876
# 16        Silt      NaN            NaN        1.446322
# 25       Loamy      NaN      57.974580        0.554656
# ...        ...      ...            ...             ...
# 9963     Sandy      NaN      52.502438        1.382132
# 9966     Loamy      NaN      17.875764        1.104878
# 9975      Clay      NaN            NaN        1.277145
# 9993     Loamy      NaN      19.139848        0.590882
# 9995      Silt      NaN      36.331983        0.745274
#
#       Electrical_Conductivity  Nitrogen_Level  Phosphorus_Level  \
# 0                    1.197623       61.326369         33.637166
# 7                    2.839372       41.727987         66.073011
# 11                        NaN       69.420714         70.262067
# ...

# %%
data['Soil_pH'].fillna(data['Soil_pH'].median(),inplace=True)
# Out:
# /tmp/ipykernel_4796/2605671348.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Soil_pH'].fillna(data['Soil_pH'].median(),inplace=True)

# %%
data['Soil_pH'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Soil_Moisture'].fillna(data['Soil_Moisture'].median(),inplace=True)
# Out:
# /tmp/ipykernel_4796/2110732483.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Soil_Moisture'].fillna(data['Soil_Moisture'].median(),inplace=True)

# %%
data['Soil_Moisture'].isnull().sum()
# Out:
# np.int64(0)

# %%
data
# Out:
#      Soil_Type    Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0         Clay   6.511261      23.176586        0.335118
# 1         Silt   5.453217      57.352151        0.245066
# 2          NaN   8.229938      41.595209        1.114318
# 3         Clay   5.097788      13.897686        1.229014
# 4          NaN   7.594949      35.595219        0.883794
# ...        ...        ...            ...             ...
# 9995      Silt   6.511261      36.331983        0.745274
# 9996      Clay   4.784560      35.595219        0.928590
# 9997    Loamy-  78.346197      40.385449        1.144741
# 9998     Loamy   8.020147      47.152632        1.587846
# 9999     Sandy   5.727448      72.451710        1.039178
#
#       Electrical_Conductivity  Nitrogen_Level  Phosphorus_Level  \
# 0                    1.197623       61.326369         33.637166
# 1                    0.187012             NaN         48.048418
# 2                    2.125256       42.623678               NaN
# ...

# %%
data['Organic_Carbon'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Organic_Carbon'].fillna(data['Organic_Carbon'].median(),inplace=True)
# Out:
# /tmp/ipykernel_4796/4065175796.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Organic_Carbon'].fillna(data['Organic_Carbon'].median(),inplace=True)

# %%
data['Electrical_Conductivity'].fillna(data['Electrical_Conductivity'].median(),inplace=True)
# Out:
# /tmp/ipykernel_4796/952966633.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Electrical_Conductivity'].fillna(data['Electrical_Conductivity'].median(),inplace=True)

# %%
data['Nitrogen_Level'].fillna(data['Nitrogen_Level'].median(),inplace=True)
# Out:
# /tmp/ipykernel_4796/1749259578.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Nitrogen_Level'].fillna(data['Nitrogen_Level'].median(),inplace=True)

# %%
data['Phosphorus_Level'].fillna(data['Phosphorus_Level'].median(),inplace=True)
# Out:
# /tmp/ipykernel_4796/4220405255.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Phosphorus_Level'].fillna(data['Phosphorus_Level'].median(),inplace=True)

# %%
data['Temperature'].fillna(data['Temperature'].median(),inplace=True)
# Out:
# /tmp/ipykernel_4796/535127503.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Temperature'].fillna(data['Temperature'].median(),inplace=True)

# %%
data['Potassium_Level'].fillna(data['Potassium_Level'].median(),inplace=True)
# Out:
# /tmp/ipykernel_4796/2165654622.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Potassium_Level'].fillna(data['Potassium_Level'].median(),inplace=True)

# %%
data['Humidity'].fillna(data['Humidity'].median(),inplace=True)
# Out:
# /tmp/ipykernel_4796/2208946752.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Humidity'].fillna(data['Humidity'].median(),inplace=True)

# %%
data['Rainfall'].fillna(data['Rainfall'].median(),inplace=True)
# Out:
# /tmp/ipykernel_4796/3549516806.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Rainfall'].fillna(data['Rainfall'].median(),inplace=True)

# %%
data['Fertilizer_Used_Last_Season'].fillna(data['Fertilizer_Used_Last_Season'].median(),inplace=True)
# Out:
# /tmp/ipykernel_4796/2325189487.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Fertilizer_Used_Last_Season'].fillna(data['Fertilizer_Used_Last_Season'].median(),inplace=True)

# %%
data['Yield_Last_Season'].fillna(data['Yield_Last_Season'].median(),inplace=True)
# Out:
# /tmp/ipykernel_4796/3716055556.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Yield_Last_Season'].fillna(data['Yield_Last_Season'].median(),inplace=True)

# %%
data.isnull().sum()
# Out:
# Soil_Type                      0
# Soil_pH                        0
# Soil_Moisture                  0
# Organic_Carbon                 0
# Electrical_Conductivity        0
# Nitrogen_Level                 0
# Phosphorus_Level               0
# Potassium_Level                0
# Temperature                    0
# Humidity                       0
# Rainfall                       0
# Crop_Type                      0
# Crop_Growth_Stage              0
# Season                         0
# Irrigation_Type                0
# Previous_Crop                  0
# Region                         0
# Fertilizer_Used_Last_Season    0
# Yield_Last_Season              0
# Recommended_Fertilizer         0
# dtype: int64

# %%
data
# Out:
#      Soil_Type    Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0         Clay   6.511261      23.176586        0.335118
# 1         Silt   5.453217      57.352151        0.245066
# 2          NaN   8.229938      41.595209        1.114318
# 3         Clay   5.097788      13.897686        1.229014
# 4          NaN   7.594949      35.595219        0.883794
# ...        ...        ...            ...             ...
# 9995      Silt   6.511261      36.331983        0.745274
# 9996      Clay   4.784560      35.595219        0.928590
# 9997    Loamy-  78.346197      40.385449        1.144741
# 9998     Loamy   8.020147      47.152632        1.587846
# 9999     Sandy   5.727448      72.451710        1.039178
#
#       Electrical_Conductivity  Nitrogen_Level  Phosphorus_Level  \
# 0                    1.197623       61.326369         33.637166
# 1                    0.187012       89.232225         48.048418
# 2                    2.125256       42.623678         48.982637
# ...

# %%
data['Soil_Type'].fillna(data['Soil_Type'].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_4796/1225177325.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Soil_Type'].fillna(data['Soil_Type'].mode()[0],inplace=True)

# %%
data['Soil_Type'].isnull().sum()
# Out:
# np.int64(0)

# %%
data['Crop_Type'].fillna(data['Crop_Type'].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_4796/3293455588.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Crop_Type'].fillna(data['Crop_Type'].mode()[0],inplace=True)

# %%
data['Crop_Growth_Stage'].fillna(data['Crop_Growth_Stage'].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_4796/3029255127.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Crop_Growth_Stage'].fillna(data['Crop_Growth_Stage'].mode()[0],inplace=True)

# %%
data['Season'].fillna(data['Season'].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_4796/463054340.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Season'].fillna(data['Season'].mode()[0],inplace=True)

# %%
data['Irrigation_Type'].fillna(data['Irrigation_Type'].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_4796/3030797395.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Irrigation_Type'].fillna(data['Irrigation_Type'].mode()[0],inplace=True)

# %%
data['Region'].fillna(data['Region'].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_4796/2642425233.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Region'].fillna(data['Region'].mode()[0],inplace=True)

# %%
data['Previous_Crop'].fillna(data['Previous_Crop'].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_4796/2203613129.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Previous_Crop'].fillna(data['Previous_Crop'].mode()[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# Soil_Type                        0
# Soil_pH                          0
# Soil_Moisture                    0
# Organic_Carbon                   0
# Electrical_Conductivity          0
# Nitrogen_Level                   0
# Phosphorus_Level                 0
# Potassium_Level                  0
# Temperature                      0
# Humidity                         0
# Rainfall                         0
# Crop_Type                        0
# Crop_Growth_Stage                0
# Season                           0
# Irrigation_Type                  0
# Previous_Crop                    0
# Region                           0
# Fertilizer_Used_Last_Season      0
# Yield_Last_Season                0
# Recommended_Fertilizer         936
# dtype: int64

# %%
data.dropna(subset=['Recommended_Fertilizer'],inplace=True)

# %%
data.isnull().sum()
# Out:
# Soil_Type                      0
# Soil_pH                        0
# Soil_Moisture                  0
# Organic_Carbon                 0
# Electrical_Conductivity        0
# Nitrogen_Level                 0
# Phosphorus_Level               0
# Potassium_Level                0
# Temperature                    0
# Humidity                       0
# Rainfall                       0
# Crop_Type                      0
# Crop_Growth_Stage              0
# Season                         0
# Irrigation_Type                0
# Previous_Crop                  0
# Region                         0
# Fertilizer_Used_Last_Season    0
# Yield_Last_Season              0
# Recommended_Fertilizer         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9064 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Soil_Type                    9064 non-null   object
#  1   Soil_pH                      9064 non-null   float64
#  2   Soil_Moisture                9064 non-null   float64
#  3   Organic_Carbon               9064 non-null   float64
#  4   Electrical_Conductivity      9064 non-null   float64
#  5   Nitrogen_Level               9064 non-null   float64
#  6   Phosphorus_Level             9064 non-null   float64
#  7   Potassium_Level              9064 non-null   float64
#  8   Temperature                  9064 non-null   float64
#  9   Humidity                     9064 non-null   float64
#  10  Rainfall                     9064 non-null   float64
#  11  Crop_Type                    9064 non-null   object
# ...

# %% [markdown]
# removing special characters

# %%
obj_cols=data.select_dtypes(include=['object']).columns
for col in obj_cols:
    #remove special characters
    data[col]=data[col].str.replace(r'[^a-zA-Z ]','',regex=True)
    data[col]=data[col].str.strip()

# %%
for col in obj_cols:
    print(col,data[col].unique())
# Out:
# Soil_Type ['Clay' 'Silt' 'Sandy' 'Loamy' 'nan']
# Crop_Type ['Cotton' 'Maize' 'Wheat' 'Rice' 'Potato' 'Sugarcane' 'Tomato' 'nan']
# Crop_Growth_Stage ['Harvest' 'Vegetative' 'Flowering' 'Sowing' 'nan']
# Season ['Kharif' 'Zaid' 'Rabi' 'nan']
# Irrigation_Type ['Canal' 'Sprinkler' 'Rainfed' 'Drip' 'nan']
# Previous_Crop ['Wheat' 'Potato' 'Tomato' 'Sugarcane' 'Cotton' 'Maize' 'Rice' 'nan']
# Region ['South' 'Central' 'West' 'North' 'East' 'nan']
# Recommended_Fertilizer ['MOP' 'Urea' 'Compost' 'NPK' 'DAP' 'Zinc Sulphate' 'nan' 'SSP']

# %%
data
# Out:
#      Soil_Type    Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0         Clay   6.511261      23.176586        0.335118
# 1         Silt   5.453217      57.352151        0.245066
# 2         Silt   8.229938      41.595209        1.114318
# 3         Clay   5.097788      13.897686        1.229014
# 5         Silt  78.346197      20.830018        0.247308
# ...        ...        ...            ...             ...
# 9994      Silt   9.540871      12.036884        0.564536
# 9996      Clay   4.784560      35.595219        0.928590
# 9997     Loamy  78.346197      40.385449        1.144741
# 9998     Loamy   8.020147      47.152632        1.587846
# 9999     Sandy   5.727448      72.451710        1.039178
#
#       Electrical_Conductivity  Nitrogen_Level  Phosphorus_Level  \
# 0                    1.197623       61.326369         33.637166
# 1                    0.187012       89.232225         48.048418
# 2                    2.125256       42.623678         48.982637
# ...

# %%
data.isnull().sum()
# Out:
# Soil_Type                      0
# Soil_pH                        0
# Soil_Moisture                  0
# Organic_Carbon                 0
# Electrical_Conductivity        0
# Nitrogen_Level                 0
# Phosphorus_Level               0
# Potassium_Level                0
# Temperature                    0
# Humidity                       0
# Rainfall                       0
# Crop_Type                      0
# Crop_Growth_Stage              0
# Season                         0
# Irrigation_Type                0
# Previous_Crop                  0
# Region                         0
# Fertilizer_Used_Last_Season    0
# Yield_Last_Season              0
# Recommended_Fertilizer         0
# dtype: int64

# %%
data=pd.read_csv("/home/user/Downloads/fertilizer_recommendation.csv")

# %%
data.to_csv("/home/user/Downloads/fertilizer_recommendation.csv",index=False)

# %%
data
# Out:
#      Soil_Type    Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0         Clay   6.511261      23.176586        0.335118
# 1         Silt   5.453217      57.352151        0.245066
# 2         Silt   8.229938      41.595209        1.114318
# 3         Clay   5.097788      13.897686        1.229014
# 4         Silt  78.346197      20.830018        0.247308
# ...        ...        ...            ...             ...
# 9059      Silt   9.540871      12.036884        0.564536
# 9060      Clay   4.784560      35.595219        0.928590
# 9061     Loamy  78.346197      40.385449        1.144741
# 9062     Loamy   8.020147      47.152632        1.587846
# 9063     Sandy   5.727448      72.451710        1.039178
#
#       Electrical_Conductivity  Nitrogen_Level  Phosphorus_Level  \
# 0                    1.197623       61.326369         33.637166
# 1                    0.187012       89.232225         48.048418
# 2                    2.125256       42.623678         48.982637
# ...

# %%
data['Soil_Type'].unique()
# Out:
# array(['Clay', 'Silt', 'Sandy', 'Loamy', nan], dtype=object)

# %%
data['Crop_Type'].unique()
# Out:
# array(['Cotton', 'Maize', 'Wheat', 'Rice', 'Potato', 'Sugarcane',
#        'Tomato'], dtype=object)

# %%
data['Crop_Growth_Stage'].unique()
# Out:
# array(['Harvest', 'Vegetative', 'Flowering', 'Sowing'], dtype=object)

# %%
data['Season'].unique()
# Out:
# array(['Kharif', 'Zaid', 'Rabi'], dtype=object)

# %%
data['Previous_Crop'].unique()
# Out:
# array(['Wheat', 'Potato', 'Tomato', 'Sugarcane', 'Cotton', 'Maize',
#        'Rice'], dtype=object)

# %%
data['Region'].unique()
# Out:
# array(['South', 'Central', 'West', 'North', 'East'], dtype=object)

# %%
data['Irrigation_Type'].unique()
# Out:
# array(['Canal', 'Sprinkler', 'Rainfed', 'Drip'], dtype=object)

# %%
data['Recommended_Fertilizer'].unique()
# Out:
# array(['MOP', 'Urea', 'Compost', 'NPK', 'DAP', 'Zinc Sulphate', 'SSP'],
#       dtype=object)

# %%
import numpy as np

# %%
data['Season'].replace('nan',np.nan)
# Out:
# 0       Kharif
# 1       Kharif
# 2       Kharif
# 3         Zaid
# 4         Zaid
#          ...
# 9059      Zaid
# 9060      Zaid
# 9061      Rabi
# 9062      Rabi
# 9063    Kharif
# Name: Season, Length: 9064, dtype: object

# %%
data['Season'].replace('nan',np.nan)
# Out:
# 0       Kharif
# 1       Kharif
# 2       Kharif
# 3         Zaid
# 5         Zaid
#          ...
# 9994      Zaid
# 9996      Zaid
# 9997      Rabi
# 9998      Rabi
# 9999    Kharif
# Name: Season, Length: 9064, dtype: object

# %%
data['Season'].unique()
# Out:
# array(['Kharif', 'Zaid', 'Rabi'], dtype=object)

# %%
data
# Out:
#      Soil_Type    Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0         Clay   6.511261      23.176586        0.335118
# 1         Silt   5.453217      57.352151        0.245066
# 2         Silt   8.229938      41.595209        1.114318
# 3         Clay   5.097788      13.897686        1.229014
# 5         Silt  78.346197      20.830018        0.247308
# ...        ...        ...            ...             ...
# 9994      Silt   9.540871      12.036884        0.564536
# 9996      Clay   4.784560      35.595219        0.928590
# 9997     Loamy  78.346197      40.385449        1.144741
# 9998     Loamy   8.020147      47.152632        1.587846
# 9999     Sandy   5.727448      72.451710        1.039178
#
#       Electrical_Conductivity  Nitrogen_Level  Phosphorus_Level  \
# 0                    1.197623       61.326369         33.637166
# 1                    0.187012       89.232225         48.048418
# 2                    2.125256       42.623678         48.982637
# ...

# %%
data['Recommended_Fertilizer'].replace('nan',np.nan)
# Out:
# 0        MOP
# 1       Urea
# 2       Urea
# 3        MOP
# 5       Urea
#         ...
# 9994    Urea
# 9996    Urea
# 9997    Urea
# 9998     NPK
# 9999     MOP
# Name: Recommended_Fertilizer, Length: 9064, dtype: object

# %%
data['Recommended_Fertilizer'].unique()
# Out:
# array(['MOP', 'Urea', 'Compost', 'NPK', 'DAP', 'Zinc Sulphate', 'SSP'],
#       dtype=object)

# %%
data['Region'].replace('nan',np.nan)
# Out:
# 0         South
# 1       Central
# 2         South
# 3          West
# 5         North
#          ...
# 9994      North
# 9996       West
# 9997       East
# 9998       West
# 9999      South
# Name: Region, Length: 9064, dtype: object

# %%
data['Region'].unique()
# Out:
# array(['South', 'Central', 'West', 'North', 'East'], dtype=object)

# %%
data['Previous_Crop'].replace('nan',np.nan)
# Out:
# 0        Wheat
# 1       Potato
# 2       Tomato
# 3       Potato
# 5       Tomato
#          ...
# 9994      Rice
# 9996     Maize
# 9997    Cotton
# 9998     Maize
# 9999    Cotton
# Name: Previous_Crop, Length: 9064, dtype: object

# %%
data['Previous_Crop'].unique()
# Out:
# array(['Wheat', 'Potato', 'Tomato', 'Sugarcane', 'Cotton', 'Maize',
#        'Rice'], dtype=object)

# %%
data['Irrigation_Type'].replace('nan',np.nan)
# Out:
# 0           Canal
# 1       Sprinkler
# 2         Rainfed
# 3         Rainfed
# 5       Sprinkler
#           ...
# 9994      Rainfed
# 9996      Rainfed
# 9997        Canal
# 9998          NaN
# 9999        Canal
# Name: Irrigation_Type, Length: 9064, dtype: object

# %%
data['Irrigation_Type'].unique()
# Out:
# array(['Canal', 'Sprinkler', 'Rainfed', 'Drip'], dtype=object)

# %%
data['Crop_Growth_Stage'].replace('nan',np.nan)
# Out:
# 0          Harvest
# 1       Vegetative
# 2          Harvest
# 3        Flowering
# 5          Harvest
#            ...
# 9994       Harvest
# 9996       Harvest
# 9997       Harvest
# 9998    Vegetative
# 9999     Flowering
# Name: Crop_Growth_Stage, Length: 9064, dtype: object

# %%
data['Crop_Growth_Stage'].unique()
# Out:
# array(['Harvest', 'Vegetative', 'Flowering', 'Sowing'], dtype=object)

# %%
data['Crop_Type'].replace('nan',np.nan)
# Out:
# 0          Cotton
# 1           Maize
# 2          Cotton
# 3           Wheat
# 5           Wheat
#           ...
# 9994        Wheat
# 9996       Tomato
# 9997       Tomato
# 9998    Sugarcane
# 9999        Wheat
# Name: Crop_Type, Length: 9064, dtype: object

# %%
data['Crop_Type'].unique()
# Out:
# array(['Cotton', 'Maize', 'Wheat', 'Rice', 'Potato', 'Sugarcane',
#        'Tomato'], dtype=object)

# %%
data['Soil_Type'].replace('nan',np.nan)
# Out:
# 0        Clay
# 1        Silt
# 2        Silt
# 3        Clay
# 5        Silt
#         ...
# 9994     Silt
# 9996     Clay
# 9997    Loamy
# 9998    Loamy
# 9999    Sandy
# Name: Soil_Type, Length: 9064, dtype: object

# %%
data['Soil_Type'].unique()
# Out:
# array(['Clay', 'Silt', 'Sandy', 'Loamy'], dtype=object)

# %%
data.isnull().sum()
# Out:
# Soil_Type                      0
# Soil_pH                        0
# Soil_Moisture                  0
# Organic_Carbon                 0
# Electrical_Conductivity        0
# Nitrogen_Level                 0
# Phosphorus_Level               0
# Potassium_Level                0
# Temperature                    0
# Humidity                       0
# Rainfall                       0
# Crop_Type                      0
# Crop_Growth_Stage              0
# Season                         0
# Irrigation_Type                0
# Previous_Crop                  0
# Region                         0
# Fertilizer_Used_Last_Season    0
# Yield_Last_Season              0
# Recommended_Fertilizer         0
# dtype: int64

# %%
data.to_csv("/home/user/Downloads/fertilizer_recommendation.csv",index=False)

# %%
data
# Out:
#      Soil_Type    Soil_pH  Soil_Moisture  Organic_Carbon  \
# 0         Clay   6.511261      23.176586        0.335118
# 1         Silt   5.453217      57.352151        0.245066
# 2         Silt   8.229938      41.595209        1.114318
# 3         Clay   5.097788      13.897686        1.229014
# 4         Silt  78.346197      20.830018        0.247308
# ...        ...        ...            ...             ...
# 9059      Silt   9.540871      12.036884        0.564536
# 9060      Clay   4.784560      35.595219        0.928590
# 9061     Loamy  78.346197      40.385449        1.144741
# 9062     Loamy   8.020147      47.152632        1.587846
# 9063     Sandy   5.727448      72.451710        1.039178
#
#       Electrical_Conductivity  Nitrogen_Level  Phosphorus_Level  \
# 0                    1.197623       61.326369         33.637166
# 1                    0.187012       89.232225         48.048418
# 2                    2.125256       42.623678         48.982637
# ...

# %%
data.isnull().sum()
# Out:
# Soil_Type                      0
# Soil_pH                        0
# Soil_Moisture                  0
# Organic_Carbon                 0
# Electrical_Conductivity        0
# Nitrogen_Level                 0
# Phosphorus_Level               0
# Potassium_Level                0
# Temperature                    0
# Humidity                       0
# Rainfall                       0
# Crop_Type                      0
# Crop_Growth_Stage              0
# Season                         0
# Irrigation_Type                0
# Previous_Crop                  0
# Region                         0
# Fertilizer_Used_Last_Season    0
# Yield_Last_Season              0
# Recommended_Fertilizer         0
# dtype: int64
